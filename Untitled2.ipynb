# %%
# act as person a perform task b
# Out:
#   Cell In[1], line 1
#     act as person a
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df=pd.read_csv('datamooc.csv')

# %%
name='Mohammad Ahmad'

# %%
your_courses = df[(df['Name'] == name)]

# %%
your_courses
# Out:
#                   Name                     Email External Id  \
# 3282    Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 7435    Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 22408   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 29108   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 29413   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 31961   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 43648   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 46442   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 52402   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 64216   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 64469   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 69977   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 71617   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# 79625   Mohammad Ahmad  mohammad.12222686@lpu.in    12222686
# ...

# %%
name2='Sheikh Haziq'
your_courses = df[(df['Name'] == name2)]
your_courses
# Out:
#                Name                Email External Id  \
# 1959   Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 6639   Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 28236  Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 30197  Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 36835  Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 51218  Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 53117  Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 54601  Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 74288  Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 76415  Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 79240  Sheikh Haziq  sheikh.haziq@lpu.in    12209938
# 79906  Sheikh Haziq  sheikh.haziq@lpu.in    12209938
#
#                                                   Course  Overall Progress  \
# 1959    Approximation Algorithms and Linear Programming               0.00
# 6639                      Prompt Engineering for ChatGPT              8.70
# ...

# %%
Registration_No='12222493'
your_coursess = df[(df['External Id'] == Registration_No)]
your_coursess
# Out:
#          Name                  Email External Id  \
# 4460    Dhruv  dhruv.12222493@lpu.in    12222493
# 28539   Dhruv  dhruv.12222493@lpu.in    12222493
# 43514   Dhruv  dhruv.12222493@lpu.in    12222493
# 70812   Dhruv  dhruv.12222493@lpu.in    12222493
# 70815   Dhruv  dhruv.12222493@lpu.in    12222493
# 72671   Dhruv  dhruv.12222493@lpu.in    12222493
# 77770   Dhruv  dhruv.12222493@lpu.in    12222493
# 85575   Dhruv  dhruv.12222493@lpu.in    12222493
# 92060   Dhruv  dhruv.12222493@lpu.in    12222493
# 92665   Dhruv  dhruv.12222493@lpu.in    12222493
# 101134  Dhruv  dhruv.12222493@lpu.in    12222493
#
#                                                    Course  Overall Progress  \
# 4460                Introduction to Large Language Models            100.00
# 28539                                  GenAI for Everyone            100.00
# 43514                      Prompt Engineering for ChatGPT            100.00
# ...

# %%
Registration_No='12222316'
your_coursess = df[(df['External Id'] == Registration_No)]
your_coursess
# Out:
#                Name                   Email External Id  \
# 39     RASHMI DUBEY  rashmi.12222316@lpu.in    12222316
# 1254   RASHMI DUBEY  rashmi.12222316@lpu.in    12222316
# 15272  RASHMI DUBEY  rashmi.12222316@lpu.in    12222316
# 24284  RASHMI DUBEY  rashmi.12222316@lpu.in    12222316
# 56218  RASHMI DUBEY  rashmi.12222316@lpu.in    12222316
# 61157  RASHMI DUBEY  rashmi.12222316@lpu.in    12222316
# 74913  RASHMI DUBEY  rashmi.12222316@lpu.in    12222316
# 78712  RASHMI DUBEY  rashmi.12222316@lpu.in    12222316
# 79668  RASHMI DUBEY  rashmi.12222316@lpu.in    12222316
# 99785  RASHMI DUBEY  rashmi.12222316@lpu.in    12222316
#
#                                                  Course  Overall Progress  \
# 39               Dynamic Programming, Greedy Algorithms              0.00
# 1254                                 GenAI for Everyone            100.00
# 15272                    Introduction to Generative AI             100.00
# ...

# %%
df.size
# Out:
# 1151997
